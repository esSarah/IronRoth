# %%
gandalf = [10, 11, 13, 30, 22, 11, 10, 33, 22, 22]
saruman = [23, 66, 12, 43, 12, 10, 44, 23, 12, 17]

# finally free of the shackles of automated testing!

gandalf_wins = 0
saruman_wins = 0

#test if not one magican noped out before it was over
gandalf_tries = len(gandalf)
saruman_tries = len(saruman)

rounds_to_compare = 0


if(gandalf_tries!=saruman_tries):
    if(gandalf_tries < saruman_tries):
        rounds_to_compare = gandalf_tries
        saruman_wins = saruman_tries - gandalf_tries
    else:
        rounds_to_compare = saruman_tries
        gandalf_wins = gandalf_tries - saruman_tries
else:
    rounds_to_compare = gandalf_tries

for i in (range(0, rounds_to_compare)):
    if(gandalf[i]!=saruman[i]):
        if(gandalf[i]>saruman[i]:):
            gandalf_wins += 1
        else:
            saruman_wins += 1
    # else it is a tie and no one wins,
    # no action required

if(gandalf_wins==saruman_wins):
    print("Tie")
else:
    if(gandalf_wins > saruman_wins):
        print("Gandalf wins")
    else:
        print("Saruman wins")

# %%
#optional


import statistics

gandalf_power = 0
saruman_power = 0

def gandalf_wins(rounds):
    global gandalf_power
    global gandalf_wins_in_a_row  
    global saruman_wins_in_a_row
    
    gandalf_power += POWER[gandalf[rounds]]
    saruman_wins_in_a_row = 0
    gandalf_wins_in_a_row += 1 
    
    return True

def saruman_wins(rounds):
    global saruman_power
    global gandalf_wins_in_a_row  
    global saruman_wins_in_a_row
    
    saruman_power += POWER[saruman[rounds]]
    saruman_wins_in_a_row += 1
    gandalf_wins_in_a_row = 0
    
    return True

POWER = {
    'Fireball': 50, 
    'Lightning bolt': 40, 
    'Magic arrow': 10, 
    'Black Tentacles': 25, 
    'Contagion': 45
}

gandalf = ['Fireball', 'Lightning bolt', 'Lightning bolt', 'Magic arrow', 'Fireball', 
           'Magic arrow', 'Lightning bolt', 'Fireball', 'Fireball', 'Fireball']
saruman = ['Contagion', 'Contagion', 'Black Tentacles', 'Fireball', 'Black Tentacles', 
           'Lightning bolt', 'Magic arrow', 'Contagion', 'Magic arrow', 'Magic arrow']



round_of_turnament  = 0
rounds_of_turnament = 0

#test if not one magican noped out before it was over
gandalf_rounds = len(gandalf)
saruman_rounds = len(saruman)

if(gandalf_rounds>=saruman_rounds):
    rounds_of_turnament = gandalf_rounds
else:
    rounds_of_turnament = saruman_rounds

gandalf_wins_in_a_row = 0
saruman_wins_in_a_row = 0

still_another_round_to_go = True

    
while still_another_round_to_go :

    if round_of_turnament == rounds_of_turnament:
        if gandalf_power==saruman_power :
            print("Incredibly it is a Tie")
        else:
            if(gandalf_power>saruman_power):
                print("Gandalf wins the turnament")
            else:
                print("Saruman wins the turnament")
        still_another_round_to_go = False
    else:

        if(round_of_turnament>gandalf_rounds or round_of_turnament>saruman_rounds):
            if(round_to_compare>gandalf_rounds):
                saruman_wins(round_of_turnament)
                gandalf_wins(round_of_turnament)
            else:
                gandalf_wins(round_of_turnament)
                print(POWER[gandalf[round_of_turnament]])

        else:

            if(POWER[gandalf[round_of_turnament]]!=POWER[saruman[round_of_turnament]]):
                
                if(POWER[gandalf[round_to_compare]]>POWER[saruman[round_of_turnament]]):

                    gandalf_wins(round_of_turnament)
                else:

                    saruman_wins(round_of_turnament)
              #else tie and nothing happens

        if(saruman_wins_in_a_row == 3):
            print("Saruman wins the turnament")
            still_another_round_to_go = False
        if(gandalf_wins_in_a_row == 3):
            print("Gandalf wins the turnament")
            still_another_round_to_go = False


    round_of_turnament += 1

gandalfHits = [POWER[spell] for spell in gandalf ]       
sarumanfHits = [POWER[spell] for spell in saruman ]     


print("Mean Gandalf = " + str(statistics.mean(gandalfHits)))
print("Mean Saruman = " + str(statistics.mean(sarumanfHits)))

print("Standard Deviation Gandalf = " + str(statistics.stdev(gandalfHits)))
print("Standard Deviation Median Saruman = " +str(statistics.stdev(sarumanfHits)))

    
        
        
        
        
    

#after 3 wins in a row the duel is over
# Out:
# Gandalf wins the turnament
# Mean Gandalf = 39
# Mean Saruman = 30.5
# Standard Deviation Gandalf = 15.951314818673865
# Standard Deviation Median Saruman = 16.40629960309962
